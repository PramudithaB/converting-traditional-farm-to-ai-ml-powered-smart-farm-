# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="B3AK2lkHdqLr3fZeXChP")
project = rf.workspace("cattle-diseasee-computer-vision-dataset").project("cattle-dataset-behavior-cqtzu")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 50.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 63.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 92.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to cattle-dataset-behavior-1 in yolov8:: 100%|██████████| 7634/7634 [00:01<00:00, 7343.92it/s]

# %%
pip install ultralytics opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 60.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
from google.colab import drive



# 2. Load Model
model = YOLO('yolov8s.pt')

# 3. Train with optimized epochs
results = model.train(
    data='/content/cattle-dataset-behavior-1/data.yaml',
    epochs=150,   
    batch=32,
    patience=30,   # Epochs 30 (Save time)

    # Save Settings
    project='/content/drive/MyDrive/My_dataset_behavior',
    name='cattle_behavior_model_v2' # Version 2 kiyala damma
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA L4, 22693MiB)
# ...

# %%
from ultralytics import YOLO


model = YOLO('/content/drive/MyDrive/My_dataset_behavior/cattle_behavior_model_v2/weights/best.pt')


model.train(data='/content/cattle-dataset-behavior-1/data.yaml',
            epochs=100,      
            imgsz=640,
            patience=50,      
            batch=16)
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA L4, 22693MiB)
# ...

# %%
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow

model_path = '/content/drive/MyDrive/My_dataset_behavior/cattle_behavior_model_v2/weights/best.pt'
model = YOLO(model_path)

source_file = '/content/cattle-dataset-behavior-1/test/images/Standing-95-_jpg.rf.5f4e92db702817ed567c73f688754920.jpg'  # <--- මෙතනට ඔයා Upload කරපු ෆයිල් එකේ නම හෝ Path එක දෙන්න



results = model.predict(source=source_file, save=True, conf=0.5)

for result in results:
    img = result.plot() 
    cv2_imshow(img)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
#
# image 1/1 /content/cattle-dataset-behavior-1/test/images/Standing-95-_jpg.rf.5f4e92db702817ed567c73f688754920.jpg: 640x640 5 eatings, 2 standings, 7.7ms
# Speed: 8.4ms preprocess, 7.7ms inference, 50.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict
# <PIL.Image.Image image mode=RGB size=512x512>
